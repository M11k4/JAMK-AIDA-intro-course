# %% [markdown]
# ## Exercise 7 - Data visualization
# - Different data sources will be utilized in this exercise.
# - **Important**: Remember to adjust the size of each visualized graph using figsize parameter for plot method for better viewing experience!

# %% [markdown]
# 1 Read the earthquakes.csv file and save its content into a variable. Then use bar chart to visualize magnitude values being 8.2 or over so that date values will be presented in x-axle and magnitude in y-axle.

# %%
import pandas as pd
#import numpy as np

quakes = pd.read_csv("data_files/earthquakes.csv",delimiter=",")
#mags = quakes["Magnitude"].to_numpy()

graphquakes = quakes[quakes['Magnitude']>=8.2]

graphquakes.loc[:,['Magnitude','Date']].plot(kind='bar',x='Date', figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# 2) Read the gamedata.json file to a new variable. Visualize the data with pie chart so that share count will be counted for each Steam rating (in other words how many percentage out of all games have received which rating).
#
# (Here's my interpretation of this task: Read the gamedata.json file into a new variable. Visualize the data of the "steamRatingText" column as a piechart, so that each slice of the pie shows which percentage of games have received the same worded rating.)

# %%
import json
import numpy as np

with open('data_files/gamedata.json') as gamedata:
    gdata = json.load(gamedata)
    
gamed = pd.DataFrame(gdata)

#gamed

counts = gamed['steamRatingText'].value_counts()

#näin vähän mutkan kautta tein nämä laskut tällä kertaa, ja nyt palautan nämä tiedot uuteen DataFrameen:

counted = pd.DataFrame({"steamRatingText":counts.index,
                        "ratingOccurances":counts.values})
#counted

label_list = [str(round(100 * (i / sum(counts)),1)) + ' %' for i in counts]
       
counted.plot(kind="pie",y="ratingOccurances",labels=label_list).legend(counts.index, bbox_to_anchor=(1.5, 1), loc='upper right')

# %% [markdown]
# 3) Use the same game_data.json as above and create a scatter plot where you compare the relationships for metacriticScore and salePrice.

# %%
wert = pd.DataFrame({'metacriticScore':gamed['metacriticScore'].astype(int),
                     'salePrice':gamed['salePrice'].astype(float)})
#wert

wert.plot(kind="scatter",x="metacriticScore",y="salePrice",figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='metacriticScore', ylabel='salePrice'>

# %% [markdown]
# 4 Use earthquake data you read earlier (the unfiltered original data) and create a scatter plot for magnitude values using Longitude and Latitude values for x- and y-axles correspondingly. In addition, use colormap for magnitude values.

# %%
quakes = pd.read_csv("data_files/earthquakes.csv",delimiter=",")

quakeplotter = pd.DataFrame({'Longitude':quakes['Longitude'].astype(float),
                             'Latitude':quakes['Latitude'].astype(float),
                             'Magnitude':quakes['Magnitude'].astype(float)})
quakeplotter = quakeplotter.sort_values(by='Magnitude')
#quakeplotter

quakeplotter.plot(kind="scatter",x='Longitude',y='Latitude',figsize=(9,5),c='Magnitude',colormap="gist_heat")
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>
